# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui
import time
import os
mailler = ["yesmininstermlh@mail.com.tr","brooklynninenine@mail.com.tr"]
sifre = "MlH0305AlA."
for i in mailler:
    chrome_option = webdriver.ChromeOptions()
    chrome_option.add_argument('--incognito')
    driver = webdriver.Chrome("C:\\Users\\user\\Desktop\\DailyBot\\chromedriver.exe", options=chrome_option)
    driver.get("https://www.dailymotion.com/signin?urlback=%2Ftr")
    time.sleep(3)
    driver.maximize_window()
    time.sleep(3)
    eposta = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > div.EmailInput__container___1o28e.EmailSignin__fieldContainer___EiNVG > input")
    eposta.click()
    eposta.send_keys(i)
    password = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > div.PasswordInput__container___3h8ES.EmailSignin__fieldContainer___EiNVG > input")
    password.click()
    time.sleep(1)
    password.send_keys(sifre)
    time.sleep(3)
    oturumac = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > button > span")
    oturumac.click()
    time.sleep(5) 
    driver.get("https://www.dailymotion.com/partner")
    time.sleep(5)
    yukle = driver.find_element_by_css_selector("#react-root > div > section > aside > div > div > div:nth-child(1) > div:nth-child(2) > a > button")
    yukle.click()
    time.sleep(3)
    if i == "yesmininstermlh@mail.com.tr":
        ilkvideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[2]).replace("-"," ")[0:-4]
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
            
            
    elif i == "brooklynninenine@mail.com.tr":
        ilkvideo = "C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\brooklynninenine@mail.com.tr")[2]).replace("-"," ")[0:-4]
        
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-0884b4b07d98> in <module>
#      36         ikincivideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[1])
#      37         ikincivideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[1]).replace("-"," ")[0:-4]
# ---> 38         ücüncüvideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[2])
#      39         ücüncüvideoisim = (os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[2]).replace("-"," ")[0:-4]
#      40         videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import os
import pyautogui

ilkvideo = "C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr\\"+(os.listdir("C:\\Users\\user\\Desktop\\Videolar\\yesmininstermlh@mail.com.tr")[0])
print(ilkvideo)
# Out:
# C:\Users\user\Desktop\Videolar\yesmininstermlh@mail.com.tr\Det-Dave-Majors-S01E21.mp4

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import os
import pyautogui

pyautogui.moveTo(1851,508)  
time.sleep(2)
pyautogui.click(button='left',clicks=1)
time.sleep(10)
pyautogui.scroll(-1)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui
import time
import os
mailler = ["bigproject01@mail.com.tr","bigproject02@mail.com.tr","bigproject03@mail.com.tr","bigproject04@mail.com.tr","bigproject05@mail.com.tr",
          "bigproject06@mail.com.tr","bigproject07@mail.com.tr","bigproject08@mail.com.tr","bigproject09@mail.com.tr","bigproject10@mail.com.tr",
          "channelalaolu01@mail.com.tr","channelalaolu02@mail.com.tr","channelalaolu03@mail.com.tr","channelalaolu04@mail.com.tr","channelalaolu05@mail.com.tr",
          "channelalaolu06@mail.com.tr","channelalaolu07@mail.com.tr","channelalaolu08@mail.com.tr","channelalaolu09@mail.com.tr","channelalaolu10@mail.com.tr",
          "johnsmith01@mail.com.tr","johnsmith02@mail.com.tr","johnsmith03@mail.com.tr","johnsmith04@mail.com.tr","johnsmith05@mail.com.tr",
          "johnsmith0606@mail.com.tr","johnsmith0707@mail.com.tr","johnsmith0808@mail.com.tr","johnsmith0909@mail.com.tr","johnsmith1010@mail.com.tr",
          "siriuscat0101@mail.com.tr","siriuscat0202@mail.com.tr","siriuscat0303@mail.com.tr","siriuscat0404@mail.com.tr","siriuscat0505@mail.com.tr",
          "siriuscat0606@mail.com.tr","siriuscat0707@mail.com.tr","siriuscat0808@mail.com.tr","siriuscat0909@mail.com.tr","siriuscat1010@mail.com.tr",
          "duochannel0101@mail.com.tr","duochannel0202@mail.com.tr","duochannel0303@mail.com.tr","duochannel0404@mail.com.tr","duochannel0505@mail.com.tr",
          "duochannel0606@mail.com.tr","duochannel0707@mail.com.tr","duochannel0808@mail.com.tr","duochannel0909@mail.com.tr","duochannel1010@mail.com.tr",]
sifre = "Wad09quw1211."
for i in mailler:
    chrome_option = webdriver.ChromeOptions()
    chrome_option.add_argument('--incognito')
    driver = webdriver.Chrome("C:\\Users\\computer\\Desktop\\DailyBot\\chromedriver.exe", options=chrome_option)
    driver.get("https://www.dailymotion.com/signin?urlback=%2Ftr")
    time.sleep(3)
    driver.maximize_window()
    time.sleep(3)
    eposta = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > div.EmailInput__container___1o28e.EmailSignin__fieldContainer___EiNVG > input")
    eposta.click()
    eposta.send_keys(i)
    password = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > div.PasswordInput__container___3h8ES.EmailSignin__fieldContainer___EiNVG > input")
    password.click()
    time.sleep(1)
    password.send_keys(sifre)
    time.sleep(3)
    oturumac = driver.find_element_by_css_selector("#root > div > div.Root__page___1mPV6.Root__sticky___SN_EF > div > div > div > div.ShortSigninFlow__topContainer___d5YEG > form > div > button > span")
    oturumac.click()
    time.sleep(5) 
    driver.get("https://www.dailymotion.com/partner")
    time.sleep(5)
    yukle = driver.find_element_by_css_selector("#react-root > div > section > aside > div > div > div:nth-child(1) > div:nth-child(2) > a > button")
    yukle.click()
    time.sleep(3)
    if i == "bigproject01@mail.com.tr":
        ilkvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject01@mail.com.tr")[2]).replace("-"," ")[0:-4]
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
            
            
    elif i == "bigproject02@mail.com.tr":
        ilkvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject02@mail.com.tr")[2]).replace("-"," ")[0:-4]
        
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
        
    
    elif i == "bigproject03@mail.com.tr":
        ilkvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject03@mail.com.tr")[2]).replace("-"," ")[0:-4]
        
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
        
     
    elif i == "bigproject04@mail.com.tr":
        ilkvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject04@mail.com.tr")[2]).replace("-"," ")[0:-4]
        
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
        
        
    elif i == "bigproject05@mail.com.tr":
        ilkvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[0])
        ilkvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[0]).replace("-"," ")[0:-4]
        ikincivideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[1])
        ikincivideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[1]).replace("-"," ")[0:-4]
        ücüncüvideo = "C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr\\"+(os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[2])
        ücüncüvideoisim = (os.listdir("C:\\Users\\computer\\Desktop\\Videolar\\bigproject05@mail.com.tr")[2]).replace("-"," ")[0:-4]
        
        videolar = [ilkvideo,ilkvideoisim],[ikincivideo,ikincivideoisim],[ücüncüvideo,ücüncüvideoisim]
        
        
        for video, videoismi in videolar:
            driver.find_element_by_css_selector("#upload__upload-zone > input[type=file]").send_keys(video)
            time.sleep(3)
            videobaslik = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(1) > div > div > input")
            videobaslik.click()
            time.sleep(1)
            pyautogui.hotkey('ctrl','a')
            time.sleep(1)
            pyautogui.press('delete')
            time.sleep(1)
            videobaslik.send_keys(videoismi)
            time.sleep(2)
            aciklama = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-16.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div > textarea")
            aciklama.send_keys(videoismi)
            time.sleep(5)
            kategori = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__tabs--2M-wd > div.src-routes-media-common-components-video-edit-form-tabs-form-index__tabs--2Dc_5 > div > div > div.ant-col.ant-col-xs-24.ant-col-xs-offset-0.ant-col-lg-8.ant-col-lg-offset-0 > div > div:nth-child(2) > div > div.src-common-services-decoFields-index__wrappedcomp--1oNvz > span > div")
            kategori.click()
            time.sleep(1)
            tvvedizi = driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div > ul > li:nth-child(15)")
            tvvedizi.click()
            time.sleep(5)
            kontrol = [*range(100)]
            for a in kontrol:
                bitti = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-common-components-progress-bar-index__progress--1l993 > span.src-routes-media-common-components-progress-bar-index__message--1zk1W > span").text
                if bitti == "Bitti":
                    break      
                else:
                    time.sleep(8)
            yayınla = driver.find_element_by_css_selector("#react-root > div > section > main > div > div > div > div > div.src-routes-media-pages-upload-components-slot-index__slot--2_CGn > div.src-routes-media-pages-upload-components-slot-index__container--1Wwl3.src-routes-media-pages-upload-components-slot-index__open--33mgz > div.src-routes-media-pages-upload-components-slot-index__actions--23hKy > div > span > button")
            yayınla.click()
            time.sleep(10)
            yukle.click()
        driver.quit() 
        time.sleep(2)
        os.unlink(ilkvideo)
        time.sleep(1)
        os.unlink(ikincivideo)
        time.sleep(1)
        os.unlink(ücüncüvideo)
        time.sleep(1)
